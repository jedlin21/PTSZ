# %%
import numpy as np
import time
import copy
import random
import sys

# %%
nSamples = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
machineNames = ['m0','m1','m2','m3','m4']

# %%
# p - persistance
# r - ready time

# Cj oznacza moment zakończenia wykonywania zadania Jj w uszeregowaniu

# p r 
# r  >= c - p

# %% [markdown]
# # Generate

# %%
for x in nSamples:
    timeCounter = 0
    fileData = []
    fileData.append(x)
    for _ in range(x):
        p = np.random.randint(1, 100)
        r = np.random.randint(timeCounter - 5 if timeCounter - 5 > 0 else 0 ,timeCounter + 2)
        timeCounter += int(p/3)
        
        fileData.append([p,r])
        
    with open(f'PTSZ-instancje/136723/in136723_{x}.txt', "w") as f:
        f.write(f"{str(fileData[0])}\n")
        
        m0 = np.random.randint(25,100)
        m1 = np.random.randint(25,100)
        m2 = np.random.randint(25,30)
        m3 = np.random.randint(25,100)
        m4 = np.random.randint(99,100)
        machines = np.array([m0,m1,m2,m3,m4])
        machines =  machines /max(machines)
        machines = np.random.choice( machines, 5, replace=False )
        f.write(f"{' '.join([str(x) for x in machines])}\n")
        
        instances = fileData[1:]
        random.shuffle(instances)
        for line in instances:            
            f.write(f"{' '.join([str(x) for x in line])}\n")

# %% [markdown]
# # Verify

# %%
x = 50

# %%
data
# Out:
# {1: {'p': 9, 'r': 6, 'c': 13.043478260869566, 'w': 7.043478260869566},
#  2: {'p': 40, 'r': 7, 'c': 70.97101449275362, 'w': 63.971014492753625},
#  3: {'p': 29, 'r': 117, 'c': 2097.0289855072465, 'w': 1980.0289855072465},
#  4: {'p': 33, 'r': 161, 'c': 2526.8260869565215, 'w': 2365.8260869565215},
#  5: {'p': 10, 'r': 37, 'c': 417.4927536231884, 'w': 380.4927536231884},
#  6: {'p': 48, 'r': 205, 'c': 3155.5652173913045, 'w': 2950.5652173913045},
#  7: {'p': 37, 'r': 86, 'c': 1464.623188405797, 'w': 1378.623188405797},
#  8: {'p': 47, 'r': 57, 'c': 759.1159420289855, 'w': 702.1159420289855},
#  9: {'p': 11, 'r': 48, 'c': 627.9420289855072, 'w': 579.9420289855072},
#  10: {'p': 10, 'r': 100, 'c': 1776.4927536231885, 'w': 1676.4927536231885},
#  11: {'p': 49, 'r': 154, 'c': 2470.014492753623, 'w': 2316.014492753623},
#  12: {'p': 23, 'r': 30, 'c': 409.3333333333333, 'w': 379.3333333333333},
#  13: {'p': 47, 'r': 181, 'c': 2875.1159420289855, 'w': 2694.1159420289855},
#  14: {'p': 14, 'r': 46, 'c': 553.2898550724638, 'w': 507.28985507246375},
#  15: {'p': 25, 'r': 29, 'c': 307.231884057971, 'w': 278.231884057971},
#  16: {'p': 24, 'r': 72, 'c': 1118.7826086956522, 'w': 1046.7826086956522},
#  17: {'p': 30, 'r': 243, 'c': 3659.478260869565, 'w': 3416.478260869565},
#  18: {'p': 30, 'r': 85, 'c': 1411.4782608695652, 'w': 1326.4782608695652},
#  19: {'p': 42, 'r': 171, 'c': 2816.8695652173915, 'w': 2645.8695652173915},
#  20: {'p': 44, 'r': 227, 'c': 3497.768115942029, 'w': 3270.768115942029},
#  476: {'p': 26, 'r': 7, 'c': 335.78787878787875, 'w': 328.78787878787875},
#  477: {'p': 28, 'r': 26, 'c': 642.8484848484849, 'w': 616.8484848484849},
#  478: {'p': 46, 'r': 6, 'c': 257.3939393939394, 'w': 251.39393939393938},
#  479: {'p': 44, 'r': 94, 'c': 3150.3333333333335, 'w': 3056.3333333333335},
#  480: {'p': 33, 'r': 179, 'c': 6001.0, 'w': 5822.0},
#  481: {'p': 34, 'r': 223, 'c': 7287.030303030303, 'w': 7064.030303030303},
#  482: {'p': 46, 'r': 171, 'c': 5634.393939393939, 'w': 5463.393939393939},
#  483: {'p': 20, 'r': 84, 'c': 2530.6060606060605, 'w': 2446.6060606060605},
#  484: {'p': 22, 'r': 173, 'c': 5699.666666666667, 'w': 5526.666666666667},
#  485: {'p': 6, 'r': 236, 'c': 7864.181818181818, 'w': 7628.181818181818},
#  486: {'p': 16, 'r': 54, 'c': 1517.4848484848485, 'w': 1463.4848484848485},
#  487: {'p': 47, 'r': 199, 'c': 6520.424242424242, 'w': 6321.424242424242},
#  488: {'p': 31, 'r': 67, 'c': 1888.939393939394, 'w': 1821.939393939394},
#  489: {'p': 31, 'r': 93, 'c': 2844.939393939394, 'w': 2751.939393939394},
#  490: {'p': 31, 'r': 93, 'c': 2938.939393939394, 'w': 2845.939393939394},
#  491: {'p': 34, 'r': 232, 'c': 7796.030303030303, 'w': 7564.030303030303},
#  492: {'p': 14, 'r': 111, 'c': 3670.4242424242425, 'w': 3559.4242424242425},
#  493: {'p': 12, 'r': 113, 'c': 3705.3636363636365, 'w': 3592.3636363636365},
#  494: {'p': 1, 'r': 215, 'c': 6826.030303030303, 'w': 6611.030303030303},
#  495: {'p': 38, 'r': 109, 'c': 3629.151515151515, 'w': 3520.151515151515},
#  496: {'p': 6, 'r': 71, 'c': 2040.181818181818, 'w': 1969.181818181818},
#  497: {'p': 12, 'r': 69, 'c': 1923.3636363636363, 'w': 1854.3636363636363},
#  498: {'p': 26, 'r': 177, 'c': 5774.787878787879, 'w': 5597.787878787879},
#  499: {'p': 19, 'r': 82, 'c': 2380.5757575757575, 'w': 2298.5757575757575},
#  500: {'p': 44, 'r': 118, 'c': 3950.3333333333335, 'w': 3832.3333333333335}}

# %%
taskQueue
# Out:
# {}

# %%
machines
# Out:
# {'m0': {'speed': '0.69', 'readyTime': 4084.623188405797},
#  'm1': {'speed': '0.48', 'readyTime': 5487.666666666667},
#  'm2': {'speed': '1', 'readyTime': 2618.0},
#  'm3': {'speed': '0.81', 'readyTime': 3545.456790123457},
#  'm4': {'speed': '0.33', 'readyTime': 8611.333333333334}}

# %%
def calculateCost(data, taskQueue, machines):
    calculatedWeight = 0
    for key, tasks in taskQueue.items():
    #    print(f"m: {machines[key]}")
        timeCounter = 0
        #sortedTasks = sorted(tasks, key=lambda i: data[i]["r"])
        for task in tasks:
   #         print(f"task: {task}, {data[task]}")
            if machines[key]['readyTime'] > timeCounter or data[task]['r'] > timeCounter:
                timeCounter = max(machines[key]['readyTime'], data[task]['r'])
                
 #           print(f"timeCounter: {timeCounter}")
  #          print(f"machines[key]['readyTime']: {machines[key]['readyTime']}")
            
            machines[key]['readyTime'] = timeCounter + (data[task]['p'] / float(machines[key]['speed']) )
            
   #         print(f"machines[key]['readyTime']: {machines[key]['readyTime']}")
            #data[task]['r']
            data[task]['c'] = timeCounter + (data[task]['p'] / float(machines[key]['speed']) )# - data[task]['r']
            data[task]['w'] = data[task]['c'] - data[task]['r']
                  
            calculatedWeight += data[task]["w"]
            
    #        print(f"data[task]['r']: {data[task]['r']}")
     #       print(f"data[task]['c']: {data[task]['c']}")
      #      print(f"data[task]['w']: {data[task]['w']}")
       #     print(f"calculatedWeight {calculatedWeight}")
        #    print(f"real p: {(data[task]['p'] / float(machines[key]['speed']) )}")
         #   print()
        #    if timeCounter < data[task]['r']:
        #        timeCounter = data[task]['r']
            # add p time to current time
        #    timeCounter += data[task]['p']
      #      c = timeCounter
      #      data[task]['c'] = c
    
    #for key, value in data.items():
    #    print(f"{key} -> {value}")
    # check correctness
  #  if not data[task]["r"] <= data[task]["c"] - data[task]["p"]: 
  #      print("Error")

    # verify cost
   # if data[task]["c"] > data[task]["d"]:
    
    #calculatedWeight += data[task]["w"]
    #print(calculatedWeight)
    #print(calculatedWeight)
    return calculatedWeight

# %%
motherFolder = "PTSZ-instancje"
data = {}
indicies = ['136792', "136805", "136782", "136759", "136683", "136764", "136778", "136309", "136718", "136315", "136730", "132231", "136723", "136682"]
for index  in indicies:
#    print(index)
    for samples in nSamples:
        taskQueue = {}
        with open(f'{motherFolder}/{index}/out{index}_{samples}.txt', "r") as result:
            res = result.read().split('\n')
            weight = int(res[0])
            for i, name in enumerate(machineNames):
                gen = (t for t in res[i+1].split(" ") if t.isdigit())
                taskQueue[name] = [int(t) for t in gen]
    
        with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
            d = instance.read().split('\n')
            n = int(d[0])
            machines = {}
            for name, speed in zip(machineNames, d[1].split(' ')):
                machines[name] = {'speed':speed, 'readyTime':0}
            for i,line in enumerate(d[2:]):
                if line == '':
                    continue
                p,r = line.split(' ')
                p,r = int(p), int(r)
                data[i+1] = {"p": p, "r": r, "c": 0, "w":0 }
        
        calculatedWeight = calculateCost(data, taskQueue, machines)
        
        print(round(calculatedWeight / samples,2))
        #if calculatedWeight != weight:
        #    print(f"wrong weight. Calculated: {calculatedWeight}, read: {weight}")
        #else:
        #    print(f"Weight: {calculatedWeight} confirmed")
    
#    print()
#    print()
# Out:
# 51.66
# 213.1
# 238.62
# 2327.72
# 1374.19
# 1770.22
# 1007.72
# 3298.69
# 2451.79
# 13576.33
# 266.64
# 591.09
# 1055.47
# 1671.06
# 2301.81
# 2597.67
# 3464.31
# 3695.11
# 3901.47
# 4669.41
# 343.66
# 346.64
# 651.03
# 987.99
# 1021.12
# 1154.96
# 1319.07
# 1671.25
# 2052.41
# 2368.13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-3c6b146a83da> in <module>
#       8         with open(f'{motherFolder}/{index}/out{index}_{samples}.txt', "r") as result:
#       9             res = result.read().split('\n')
# ---> 10             weight = int(res[0])
#      11             for i, name in enumerate(machineNames):
#      12                 gen = (t for t in res[i+1].split(" ") if t.isdigit())
#
# ValueError: invalid literal for int() with base 10: '7.041713720052473'

# %%
readyTime = []
for i in :
    readyTime.append(self.observations[2*i+1])
#print(f"readyTime: {readyTime} theClosestTaskTime: {theClosestTaskTime} currentTime: {current_time}")
readyTime = np.array(readyTime)
try:
    minNextMachine = np.min(readyTime[readyTime > current_time])
except:
    print("except")
# Out:
# 14.234875444839856

# %%
# p - persistance
# r - ready time
# d - oczekiwany termin zakończenia
# w - weight
# Cj oznacza moment zakończenia wykonywania zadania Jj w uszeregowaniu

# p r d w
# r  >= c - p

# %% [markdown]
# # TaskScheduler

# %%
a,b,c,e,g = (1,1,1,1,1)
totalCost = 0
data = {}


indicies =['136792', "136805", "136782", "136759", "136683", "136764", "136778", "136309", "136718", "136315", "136730", "132231", "136723", "136682"]
for index  in indicies:
  
    for samples in nSamples:
        x = 0
        with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
            d = instance.read().split('\n')
            n = int(d[0])
            machines = {}
            for name, speed in zip(machineNames, d[1].split(' ')):
                machines[name] = {'speed':speed, 'readyTime':0, 'gain':0}
            for i,line in enumerate(d[2:]):
                if line == '':
                    continue
                p,r = line.split(' ')
                p,r = int(p), int(r)
                data[i+1] = {"p": p, "r": r, "c": 0, "penalty": 0 }
            sortedData = sorted(data.items(), key=lambda y: float(y[1]['r']))
            for key, value in sortedData:
                data[key]: value
            dataCopy = copy.deepcopy(data)
        
        calculatedWeight = 0
        timeCounter = 0
        outSchedule = {}
        for name in machineNames:
            outSchedule[name] = []
        
        start = time.time()
        while len(data) > 0:
            readyToGo = {}
            for key, task in data.items():
                if task['r'] <= timeCounter:
                    #endTime = timeCounter+task['p']
                    #penaltyEndTask = ( endTime if endTime > 0 else 0 ) * 1
                    penaltyPersistance = task['p']
                    task['penalty'] = b*penaltyPersistance
                    readyToGo[key] = task
                
            if len(readyToGo) == 0: # currently there is no task to go
                #print("upsi readyToGo")
                timeCounter = min(data.items(), key=lambda x: x[1]['r'])[1]['r']
                continue
            #print(f"readyToGo: {readyToGo}")

            # select task
            selectedTask = max(readyToGo.items(), key=lambda y: (y[1]['penalty']))
            
            # select machine
            readyMachines = [d for d in zip(machines.keys(), machines.values() ) if d[1]['readyTime'] <= timeCounter]
            if len(readyMachines) == 0: # currently there is no free machine
                #print("upsi readyMachines")
                timeCounter = min(machines.items(), key=lambda x: x[1]['readyTime'])[1]['readyTime']
                continue
            
            readyTime = []
            minNextMachine = np.inf
            speedNextMachine = 0
            for key, m in zip(machines.keys(),machines.values() ):
                readyTime.append(machines[key]["readyTime"])
            readyTime = np.array(readyTime)
            try:
                minNextMachine = np.min(readyTime[readyTime > timeCounter])
                ind = np.argwhere(readyTime==minNextMachine)[0][0]
                speedNextMachine = machines[f'm{ind}']['speed']
            except:
                pass
            
            for name, m in readyMachines:
                speed = machines[name]['speed']
                
                if minNextMachine != np.inf:
                    machines[name]['gain'] = c*float(speed) + e*minNextMachine + g*float(speedNextMachine)
                else:
                    machines[name]['gain'] = c*speed
            
            selectedMachine = max(readyMachines, key=lambda y: (y[1]['gain']))
            
            if machines[selectedMachine[0]]['readyTime'] > timeCounter: #selectedMachine is busy then wait
                print("WHAT THE???")
                timeCounter = machines[selectedMachine[0]]['readyTime']
                continue
            
   #         print(f"timeCounter: {timeCounter}")
       #     print(f"selectedTask: {selectedTask}")
            
            # remove task from list active tasks, add time, append outschedule
            data.pop(selectedTask[0])
            
    #        print(f"selectedMachine: {selectedMachine}")
            #timeCounter += 1
            machines[selectedMachine[0]]['readyTime'] = timeCounter + (selectedTask[1]['p'] / float(selectedMachine[1]['speed']) )
            x += (selectedTask[1]['p'] / float(selectedMachine[1]['speed']) )
     #       print(machines)
            #print(f"{selectedMachine[0]}: {selectedTask[0]}")
            
      #      print()
            
            outSchedule[selectedMachine[0]].append(selectedTask[0])    
        
        end = time.time()
        print(round((end-start)*1000))
        
        for key in machines.keys():
            machines[key]['readyTime'] = 0
        
        cost = calculateCost(dataCopy, outSchedule, machines)
        
        cost /= samples
        
       # print(round(cost))
        totalCost += cost
        
        #print(outSchedule)
        
        with open(f'out/{index}/out{index}_{samples}.txt', "w") as f:
            f.write(f"{cost}\n")         
                #f.write(f"{' '.join([str(x) for x in line])}\n")
            for name in machineNames:
                f.write(f"{' '.join([str(x) for x in outSchedule[name]])}\n")
           
        
print(totalCost)
# Out:
# 5
# 13
# 23
# 30
# 40
# 56
# 82
# 111
# 121
# 164
# 3
# 6
# 10
# 16
# 30
# 30
# 37
# 43
# 61
# 88
# 7
# 16
# 22
# 31
# 49
# 78
# 77
# 108
# 161
# 202
# 3
# 7
# 14
# 21
# 23
# 30
# 38
# 49
# 64
# 69
# 4
# 11
# 18
# 31
# 51
# 62
# 88
# 116
# 135
# 183
# 4
# 10
# 22
# 30
# 41
# 56
# 77
# 98
# 118
# 154
# 3
# 9
# 17
# 32
# 56
# 56
# 74
# 109
# 130
# 159
# 8
# 23
# 21
# 27
# 41
# 56
# 93
# 103
# 122
# 167
# 4
# 10
# 20
# 44
# 43
# 60
# 91
# 121
# 140
# 159
# 4
# 11
# 23
# 39
# 48
# 65
# 120
# 148
# 136
# 147
# 4
# 12
# 18
# 41
# 53
# 86
# 108
# 114
# 220
# 194
# 4
# 9
# 15
# 25
# 38
# 61
# 86
# 94
# 114
# 127
# 3
# 7
# 12
# 18
# 38
# 36
# 44
# 55
# 88
# 108
# 4
# 11
# 21
# 34
# 54
# 66
# 84
# 98
# 189
# 180
# 507024.036385932

# %%
machines
# Out:
# {'m0': {'speed': '0.32', 'readyTime': 185.875, 'gain': '0.32'},
#  'm1': {'speed': '0.914', 'readyTime': 248.08096280087534, 'gain': '0.914'},
#  'm2': {'speed': '1', 'readyTime': 323.0, 'gain': '1'},
#  'm3': {'speed': '0.251', 'readyTime': 170.87250996015933, 'gain': '0.251'},
#  'm4': {'speed': '0.911', 'readyTime': 228.1262349066959, 'gain': '0.911'}}

# %%
outSchedule
# Out:
# {'m0': [16, 4, 50, 40, 18],
#  'm1': [1, 32, 7, 48, 17, 34, 46, 19, 15, 20, 33, 25],
#  'm2': [28,
#   35,
#   12,
#   2,
#   11,
#   21,
#   41,
#   30,
#   47,
#   37,
#   9,
#   38,
#   31,
#   39,
#   3,
#   22,
#   24,
#   43,
#   6,
#   10,
#   26,
#   13,
#   29,
#   36],
#  'm3': [45, 27],
#  'm4': [8, 42, 49, 5, 44, 14, 23]}

# %%
selectedMachine
# Out:
# ('m2', {'speed': '1', 'readyTime': 323.0, 'gain': '1'})

# %%
data
# Out:
# {2: {'p': 8, 'r': 5862, 'c': 0, 'penalty': 0},
#  3: {'p': 1, 'r': 5864, 'c': 0, 'penalty': 0},
#  4: {'p': 14, 'r': 6771, 'c': 0, 'penalty': 0},
#  5: {'p': 1, 'r': 6777, 'c': 0, 'penalty': 0},
#  6: {'p': 2, 'r': 6777, 'c': 0, 'penalty': 0},
#  7: {'p': 13, 'r': 6777, 'c': 0, 'penalty': 0},
#  8: {'p': 11, 'r': 6784, 'c': 0, 'penalty': 0},
#  9: {'p': 13, 'r': 6789, 'c': 0, 'penalty': 0},
#  11: {'p': 4, 'r': 9724, 'c': 0, 'penalty': 0},
#  12: {'p': 8, 'r': 6169, 'c': 0, 'penalty': 0},
#  14: {'p': 4, 'r': 3871, 'c': 0, 'penalty': 0},
#  15: {'p': 2, 'r': 4319, 'c': 0, 'penalty': 0},
#  16: {'p': 14, 'r': 4320, 'c': 0, 'penalty': 0},
#  17: {'p': 12, 'r': 4323, 'c': 0, 'penalty': 0},
#  18: {'p': 5, 'r': 4334, 'c': 0, 'penalty': 0},
#  19: {'p': 5, 'r': 7220, 'c': 0, 'penalty': 0},
#  20: {'p': 14, 'r': 6521, 'c': 0, 'penalty': 0},
#  21: {'p': 12, 'r': 7282, 'c': 0, 'penalty': 0},
#  22: {'p': 3, 'r': 7288, 'c': 0, 'penalty': 0},
#  23: {'p': 8, 'r': 4543, 'c': 0, 'penalty': 0},
#  24: {'p': 13, 'r': 4545, 'c': 0, 'penalty': 0},
#  27: {'p': 6, 'r': 5753, 'c': 0, 'penalty': 0},
#  28: {'p': 14, 'r': 4908, 'c': 0, 'penalty': 0},
#  29: {'p': 10, 'r': 4910, 'c': 0, 'penalty': 0},
#  30: {'p': 1, 'r': 4911, 'c': 0, 'penalty': 0},
#  32: {'p': 11, 'r': 9596, 'c': 0, 'penalty': 0},
#  33: {'p': 12, 'r': 9015, 'c': 0, 'penalty': 0},
#  34: {'p': 12, 'r': 9023, 'c': 0, 'penalty': 0},
#  35: {'p': 7, 'r': 9024, 'c': 0, 'penalty': 0},
#  36: {'p': 3, 'r': 9025, 'c': 0, 'penalty': 0},
#  37: {'p': 10, 'r': 7063, 'c': 0, 'penalty': 0},
#  44: {'p': 8, 'r': 8019, 'c': 0, 'penalty': 0},
#  45: {'p': 2, 'r': 8025, 'c': 0, 'penalty': 0},
#  456: {'p': 8, 'r': 8873, 'c': 0, 'penalty': 0},
#  458: {'p': 2, 'r': 8603, 'c': 0, 'penalty': 0},
#  459: {'p': 2, 'r': 8603, 'c': 0, 'penalty': 0},
#  460: {'p': 2, 'r': 8604, 'c': 0, 'penalty': 0},
#  461: {'p': 3, 'r': 9356, 'c': 0, 'penalty': 0},
#  462: {'p': 13, 'r': 8751, 'c': 0, 'penalty': 0},
#  463: {'p': 3, 'r': 7551, 'c': 0, 'penalty': 0},
#  464: {'p': 7, 'r': 9372, 'c': 0, 'penalty': 0},
#  465: {'p': 5, 'r': 9378, 'c': 0, 'penalty': 0},
#  466: {'p': 3, 'r': 5105, 'c': 0, 'penalty': 0},
#  467: {'p': 8, 'r': 5106, 'c': 0, 'penalty': 0},
#  468: {'p': 1, 'r': 7266, 'c': 0, 'penalty': 0},
#  469: {'p': 6, 'r': 9843, 'c': 0, 'penalty': 0},
#  470: {'p': 8, 'r': 5382, 'c': 0, 'penalty': 0},
#  474: {'p': 12, 'r': 8928, 'c': 0, 'penalty': 0},
#  476: {'p': 6, 'r': 6489, 'c': 0, 'penalty': 0},
#  477: {'p': 8, 'r': 3430, 'c': 0, 'penalty': 0},
#  478: {'p': 11, 'r': 8533, 'c': 0, 'penalty': 0},
#  480: {'p': 3, 'r': 9443, 'c': 0, 'penalty': 0},
#  481: {'p': 10, 'r': 9443, 'c': 0, 'penalty': 0},
#  483: {'p': 9, 'r': 9573, 'c': 0, 'penalty': 0},
#  484: {'p': 7, 'r': 8587, 'c': 0, 'penalty': 0},
#  485: {'p': 5, 'r': 4992, 'c': 0, 'penalty': 0},
#  489: {'p': 14, 'r': 7736, 'c': 0, 'penalty': 0},
#  491: {'p': 6, 'r': 4664, 'c': 0, 'penalty': 0},
#  492: {'p': 6, 'r': 6345, 'c': 0, 'penalty': 0},
#  493: {'p': 1, 'r': 9069, 'c': 0, 'penalty': 0},
#  494: {'p': 6, 'r': 8934, 'c': 0, 'penalty': 0},
#  495: {'p': 3, 'r': 8936, 'c': 0, 'penalty': 0},
#  496: {'p': 8, 'r': 8937, 'c': 0, 'penalty': 0},
#  498: {'p': 4, 'r': 7473, 'c': 0, 'penalty': 0},
#  499: {'p': 11, 'r': 7476, 'c': 0, 'penalty': 0},
#  500: {'p': 3, 'r': 7483, 'c': 0, 'penalty': 0}}

# %%
x = {'m0':{'speed':2, 'readyTime':0},'m1':{'speed':3, 'readyTime':0},'m2':{'speed':1, 'readyTime':5}, }

# %%
zip(machines.keys(), machines.values() )

# %%
[d for d in x.values() if d['readyTime'] <= 0]
# Out:
# [{'speed': 2, 'readyTime': 0}, {'speed': 3, 'readyTime': 0}]

# %%
readyMachines = [d for d in x.values() if d['readyTime'] <= 0]
readyMachines = max(readyMachines, key=lambda y: (y['speed']))
readyMachines
# Out:
# {'speed': 3, 'readyTime': 0}

# %%
from scipy.optimize import minimize

# %%
x0 = (1,1,1)

# %%
def costFunction(x):
    c,e,g = x
    totalCost = 0
    data = {}

    indicies = ['136792']#, "136805", "136782", "136759", "136683", "136764", "136778", "136309", "136718", "136315", "136730", "132231", "136723", "136682"]
    for index  in indicies:
        #print()
        #print(index)
        for samples in nSamples:
            with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
                d = instance.read().split('\n')
                n = int(d[0])
                machines = {}
                for name, speed in zip(machineNames, d[1].split(' ')):
                    machines[name] = {'speed':speed, 'readyTime':0, 'gain':0}
                for i,line in enumerate(d[2:]):
                    if line == '':
                        continue
                    p,r = line.split(' ')
                    p,r = int(p), int(r)
                    data[i+1] = {"p": p, "r": r, "c": 0, "penalty": 0 }
                sortedData = sorted(data.items(), key=lambda y: float(y[1]['r']))
                for key, value in sortedData:
                    data[key]: value
                dataCopy = copy.deepcopy(data)

            calculatedWeight = 0
            timeCounter = 0
            outSchedule = {}
            for name in machineNames:
                outSchedule[name] = []

            start = time.time()
            while len(data) > 0:
                readyToGo = {}
                for key, task in data.items():
                    if task['r'] <= timeCounter:
                        #endTime = timeCounter+task['p']
                        #penaltyEndTask = ( endTime if endTime > 0 else 0 ) * 1
                        penaltyPersistance = task['p']
                        task['penalty'] = penaltyPersistance
                        readyToGo[key] = task

                if len(readyToGo) == 0: # currently there is no task to go
                    #print("upsi readyToGo")
                    timeCounter = min(data.items(), key=lambda x: x[1]['r'])[1]['r']
                    continue
                #print(f"readyToGo: {readyToGo}")

                # select task
                readyToGoSorted = sorted(readyToGo.items(), key=lambda y: (y[1]['penalty']), reverse=False)

                selectedTask = readyToGoSorted[0]

                # select machine
                readyMachines = [d for d in zip(machines.keys(), machines.values() ) if d[1]['readyTime'] <= timeCounter]
                if len(readyMachines) == 0: # currently there is no free machine
                    #print("upsi readyMachines")
                    timeCounter = min(machines.items(), key=lambda x: x[1]['readyTime'])[1]['readyTime']
                    continue

                readyTime = []
                minNextMachine = np.inf
                speedNextMachine = 0
                for key, m in zip(machines.keys(),machines.values() ):
                    readyTime.append(machines[key]["readyTime"])
                readyTime = np.array(readyTime)
                try:
                    minNextMachine = np.min(readyTime[readyTime > timeCounter])
                    ind = np.argwhere(readyTime==minNextMachine)[0][0]
                    speedNextMachine = machines[f'm{ind}']['speed']
                except:
                    pass

                for name, m in readyMachines:
                    speed = machines[name]['speed']

                    if minNextMachine != np.inf:
                        machines[name]['gain'] = c*float(speed) + e*minNextMachine + g*float(speedNextMachine)
                    else:
                        machines[name]['gain'] = c*float(speed)

                selectedMachine = max(readyMachines, key=lambda y: (y[1]['gain']))

                if machines[selectedMachine[0]]['readyTime'] > timeCounter: #selectedMachine is busy then wait
                    print("WHAT THE???")
                    timeCounter = machines[selectedMachine[0]]['readyTime']

       #         print(f"timeCounter: {timeCounter}")
           #     print(f"selectedTask: {selectedTask}")

                # remove task from list active tasks, add time, append outschedule
                data.pop(selectedTask[0])

        #        print(f"selectedMachine: {selectedMachine}")
                #timeCounter += 1
                machines[selectedMachine[0]]['readyTime'] = timeCounter + (selectedTask[1]['p'] / float(selectedMachine[1]['speed']) )
         #       print(machines)

          #      print()

                outSchedule[selectedMachine[0]].append(selectedTask[0])    

            end = time.time()
            #print(end-start)

            cost = calculateCost(dataCopy, outSchedule, machines)
            cost /= samples
            totalCost += cost
    print(f"{totalCost}   [{c},{e},{g}],")
    return totalCost

# %%
options = {"maxiter":100, "disp":True}

# %%
res = minimize(costFunction, x0, method='Powell', options=options, tol=1e-2)
# Out:
# 22847.78713007481   [100.0,110.0,-111.0],
# 22847.78713007481   [100.0,110.0,-111.0],
# 22847.78713007481   [101.0,110.0,-111.0],
# 22847.78713007481   [102.618034,110.0,-111.0],
# 22847.78713007481   [101.0,110.0,-111.0],
# 22847.78713007481   [101.0,110.0,-111.0],
# 22847.78713007481   [101.0,111.0,-111.0],
# 22847.78713007481   [101.0,112.618034,-111.0],
# 22847.78713007481   [101.0,111.0,-111.0],
# 22847.78713007481   [101.0,111.0,-111.0],
# 22847.78713007481   [101.0,111.0,-110.0],
# 22847.78713007481   [101.0,111.0,-108.381966],
# 22847.78713007481   [101.0,111.0,-110.0],
# Optimization terminated successfully.
#          Current function value: 22847.787130
#          Iterations: 1
#          Function evaluations: 13

# %%
machines.items()
# Out:
# dict_items([('m0', {'speed': '1', 'readyTime': 74328.0, 'gain': '1'}), ('m1', {'speed': '0.475', 'readyTime': 74332.6315789474, 'gain': '0.475'}), ('m2', {'speed': '0.48', 'readyTime': 74329.16666666669, 'gain': '0.48'}), ('m3', {'speed': '0.822', 'readyTime': 74328.46715328464, 'gain': '0.822'}), ('m4', {'speed': '0.582', 'readyTime': 74333.33333333328, 'gain': '0.582'})])

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]

# %%
plt.plot(x)
plt.title("Minimalizacja funkcji celu")
plt.xaxis("iteracja")
plt.yaxis("Koszt")

# %%
costFunction(x)
# Out:
# 1
# 7
# 13
# 25
# 17
# 19
# 26
# 33
# 38
# 61
# 1
# 4
# 10
# 17
# 29
# 42
# 64
# 85
# 99
# 140
# 1
# 4
# 11
# 19
# 30
# 45
# 63
# 152
# 111
# 133
# 1
# 3
# 15
# 16
# 25
# 32
# 48
# 61
# 82
# 88
# 1
# 1
# 6
# 13
# 30
# 36
# 48
# 64
# 94
# 108
# 1
# 3
# 6
# 11
# 19
# 27
# 38
# 52
# 62
# 79
# 1
# 3
# 8
# 22
# 29
# 38
# 56
# 71
# 105
# 124
# 1
# 4
# 10
# 17
# 26
# 39
# 53
# 69
# 105
# 107
# 1
# 1
# 1
# 2
# 2
# 4
# 7
# 6
# 9
# 10
# 1
# 3
# 6
# 10
# 16
# 26
# 33
# 54
# 57
# 68
# 1
# 3
# 7
# 15
# 22
# 45
# 45
# 56
# 75
# 108
# 1
# 1
# 1
# 1
# 2
# 4
# 5
# 7
# 8
# 11
# 1
# 4
# 11
# 21
# 32
# 47
# 74
# 87
# 110
# 146
# 1
# 3
# 5
# 8
# 14
# 28
# 34
# 39
# 54
# 84
# 385570

# %%
x = (-140036.8041378972, 2.5486165590751364, -0.1998934445512417, 1183)
