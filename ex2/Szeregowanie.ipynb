# %%
import numpy as np
import time
import copy
import random

# %%
nSamples = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
machineNames = ['m0','m1','m2','m3','m4']

# %%
# p - persistance
# r - ready time

# Cj oznacza moment zakończenia wykonywania zadania Jj w uszeregowaniu

# p r 
# r  >= c - p

# %% [markdown]
# # Generate

# %%
for x in nSamples:
    timeCounter = 0
    fileData = []
    fileData.append(x)
    for _ in range(x):
        p = np.random.randint(1, 100)
        r = np.random.randint(timeCounter - 5 if timeCounter - 5 > 0 else 0 ,timeCounter + 2)
        timeCounter += int(p/3)
        
        fileData.append([p,r])
        
    with open(f'PTSZ-instancje/136723/in136723_{x}.txt', "w") as f:
        f.write(f"{str(fileData[0])}\n")
        
        m0 = np.random.randint(50,100)
        m1 = np.random.randint(50,100)
        m2 = np.random.randint(50,60)
        m3 = np.random.randint(50,100)
        m4 = np.random.randint(99,100)
        machines = np.array([m0,m1,m2,m3,m4])
        machines =  machines /max(machines)
        machines = np.random.choice( machines, 5, replace=False )
        f.write(f"{' '.join([str(x) for x in machines])}\n")
        
        instances = fileData[1:]
        random.shuffle(instances)
        for line in instances:            
            f.write(f"{' '.join([str(x) for x in line])}\n")

# %% [markdown]
# # Verify

# %%
x = 50

# %%
data
# Out:
# {1: {'p': 89, 'r': 588, 'c': 1123.578947368421},
#  2: {'p': 78, 'r': 131, 'c': 519.4736842105262},
#  3: {'p': 36, 'r': 405, 'c': 1369.5263157894738},
#  4: {'p': 52, 'r': 363, 'c': 399.0},
#  5: {'p': 64, 'r': 441, 'c': 419.0},
#  6: {'p': 34, 'r': 8, 'c': 788.0},
#  7: {'p': 60, 'r': 685, 'c': 87.35294117647061},
#  8: {'p': 79, 'r': 299, 'c': 175.01470588235293},
#  9: {'p': 38, 'r': 263, 'c': 772.0},
#  10: {'p': 23, 'r': 210, 'c': 1155.0},
#  11: {'p': 21, 'r': 638, 'c': 240.57352941176475},
#  12: {'p': 24, 'r': 421, 'c': 563.9411764705883},
#  13: {'p': 39, 'r': 245, 'c': 857.7368421052631},
#  14: {'p': 4, 'r': 495, 'c': 5.012658227848078},
#  15: {'p': 23, 'r': 3, 'c': 1339.0},
#  16: {'p': 89, 'r': 496, 'c': 847.578947368421},
#  17: {'p': 49, 'r': 374, 'c': 465.1052631578947},
#  18: {'p': 5, 'r': 351, 'c': 933.0},
#  19: {'p': 12, 'r': 550, 'c': 827.0},
#  20: {'p': 11, 'r': 342, 'c': 16.014705882352928},
#  21: {'p': 61, 'r': 667, 'c': 406.8088235294117},
#  22: {'p': 31, 'r': 50, 'c': 364.0},
#  23: {'p': 40, 'r': 162, 'c': 902.0},
#  24: {'p': 71, 'r': 216, 'c': 808.0},
#  25: {'p': 45, 'r': 423, 'c': 78.15789473684208},
#  26: {'p': 5, 'r': 10, 'c': 1071.2794117647059},
#  27: {'p': 35, 'r': 489, 'c': 830.0},
#  28: {'p': 32, 'r': 351, 'c': 32.0},
#  29: {'p': 8, 'r': 102, 'c': 788.6470588235294},
#  30: {'p': 51, 'r': 710, 'c': 137.25},
#  31: {'p': 49, 'r': 572, 'c': 616.1052631578948},
#  32: {'p': 40, 'r': 393, 'c': 556.2352941176471},
#  33: {'p': 74, 'r': 274, 'c': 694.5263157894736},
#  34: {'p': 65, 'r': 550, 'c': 3217.4999999999995},
#  35: {'p': 93, 'r': 100, 'c': 853.0},
#  36: {'p': 7, 'r': 347, 'c': 167.15789473684208},
#  37: {'p': 12, 'r': 0, 'c': 1141.0},
#  38: {'p': 21, 'r': 634, 'c': 26.316455696202524},
#  39: {'p': 18, 'r': 42, 'c': 481.55696202531647},
#  40: {'p': 30, 'r': 235, 'c': 1321.1052631578948},
#  41: {'p': 59, 'r': 527, 'c': 226.47368421052636},
#  42: {'p': 47, 'r': 616, 'c': 47.0},
#  43: {'p': 47, 'r': 192, 'c': 518.0},
#  44: {'p': 63, 'r': 646, 'c': 633.0},
#  45: {'p': 64, 'r': 18, 'c': 111.15789473684208},
#  46: {'p': 36, 'r': 85, 'c': 1752.5263157894738},
#  47: {'p': 65, 'r': 322, 'c': 807.0},
#  48: {'p': 92, 'r': 55, 'c': 1448.7894736842104},
#  49: {'p': 63, 'r': 173, 'c': 1774.421052631579},
#  50: {'p': 75, 'r': 459, 'c': 757.0}}

# %%
taskQueue
# Out:
# {'m0': [28,
#   22,
#   42,
#   43,
#   4,
#   6,
#   5,
#   35,
#   24,
#   23,
#   47,
#   37,
#   50,
#   44,
#   18,
#   27,
#   15,
#   10,
#   19],
#  'm1': [20, 8, 7, 30, 11, 29, 32, 12, 21, 26],
#  'm2': [34],
#  'm3': [45, 25, 36, 2, 41, 17, 33, 9, 13, 31, 16, 48, 40, 1, 3, 46, 49],
#  'm4': [14, 39, 38]}

# %%
machines
# Out:
# {'m0': {'speed': '0.9583333333333334', 'readyTime': 0},
#  'm1': {'speed': '0.5729166666666666', 'readyTime': 0},
#  'm2': {'speed': '0.010416666666666666', 'readyTime': 0},
#  'm3': {'speed': '1.0', 'readyTime': 0},
#  'm4': {'speed': '0.20833333333333334', 'readyTime': 0}}

# %%
def calculateCost(data, taskQueue, machines):
    calculatedWeight = 0
    for key, tasks in taskQueue.items():
        print(f"m: {key}")
        timeCounter = 0
        for task in tasks:
            print(f"task: {task}, {data[task]}")
            while machines[key]['readyTime'] > timeCounter or data[task]['r'] > timeCounter:
                timeCounter += 1 
            print(f"timeCounter: {timeCounter}")
            print(f"machines[key]['readyTime']: {machines[key]['readyTime']}")
            
            machines[key]['readyTime'] = timeCounter + (data[task]['p'] / float(machines[key]['speed']) )
            
            print(f"machines[key]['readyTime']: {machines[key]['readyTime']}")
            
            data[task]['c'] = timeCounter + (data[task]['p'] / float(machines[key]['speed']) ) - data[task]['r']
            
            
            print(f"data[task]['c']: {data[task]['c']}")
            print(f"realy p: {(data[task]['p'] / float(machines[key]['speed']) )}")
            print()
        #    if timeCounter < data[task]['r']:
        #        timeCounter = data[task]['r']
            # add p time to current time
        #    timeCounter += data[task]['p']
      #      c = timeCounter
      #      data[task]['c'] = c
    
    for key, value in data.items():
        print(f"{key} -> {value}")
    # check correctness
    if not data[task]["r"] <= data[task]["c"] - data[task]["p"]: 
        print("Error")

    # verify cost
    if data[task]["c"] > data[task]["d"]:
        calculatedWeight += data[task]["w"]
    #print(calculatedWeight)
    return calculatedWeight

# %%
motherFolder = "out" # "PTSZ-instancje"
data = {}
indicies = ['136723'] #["136805", "136792", "136683", "132231", "136730", "136682", "136764", "136782", "136723", "136778", "136309", "136718", "136315", "136759"]
for index  in indicies:
    print(index)
    for samples in nSamples:
        taskQueue = {}
        with open(f'{motherFolder}/{index}/out{index}_{samples}.txt', "r") as result:
            res = result.read().split('\n')
            weight = int(res[0])
            for i, name in enumerate(machineNames):
                gen = (t for t in res[i+1].split(" ") if t.isdigit())
                taskQueue[name] = [int(t) for t in gen]
    
        with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
            d = instance.read().split('\n')
            n = int(d[0])
            machines = {}
            for name, speed in zip(machineNames, d[1].split(' ')):
                machines[name] = {'speed':speed, 'readyTime':0}
            for i,line in enumerate(d[2:]):
                if line == '':
                    continue
                p,r = line.split(' ')
                p,r = int(p), int(r)
                data[i+1] = {"p": p, "r": r, "c": 0 }
        
        calculatedWeight = calculateCost(data, taskQueue, machines)
        print(calculatedWeight)
        #if calculatedWeight != weight:
        #    print(f"wrong weight. Calculated: {calculatedWeight}, read: {weight}")
        #else:
        #    print(f"Weight: {calculatedWeight} confirmed")
    break
    print()
    print()
# Out:
# 136723
# m: m0
# task: 21, {'p': 31, 'r': 83, 'c': 0}
# timeCounter: 83
# machines[key]['readyTime']: 0
# machines[key]['readyTime']: 143.1764705882353
# data[task]['c']: 60.176470588235304
# realy p: 60.1764705882353
#
# task: 2, {'p': 67, 'r': 137, 'c': 0}
# timeCounter: 144
# machines[key]['readyTime']: 143.1764705882353
# machines[key]['readyTime']: 274.05882352941177
# data[task]['c']: 137.05882352941177
# realy p: 130.05882352941177
#
# task: 29, {'p': 65, 'r': 274, 'c': 0}
# timeCounter: 275
# machines[key]['readyTime']: 274.05882352941177
# machines[key]['readyTime']: 401.1764705882353
# data[task]['c']: 127.1764705882353
# realy p: 126.1764705882353
#
# task: 38, {'p': 37, 'r': 402, 'c': 0}
# timeCounter: 402
# machines[key]['readyTime']: 401.1764705882353
# machines[key]['readyTime']: 473.8235294117647
# data[task]['c']: 71.8235294117647
# realy p: 71.82352941176471
#
# task: 24, {'p': 33, 'r': 480, 'c': 0}
# timeCounter: 480
# machines[key]['readyTime']: 473.8235294117647
# machines[key]['readyTime']: 544.0588235294117
# data[task]['c']: 64.05882352941171
# realy p: 64.05882352941177
#
# task: 4, {'p': 71, 'r': 556, 'c': 0}
# timeCounter: 556
# machines[key]['readyTime']: 544.0588235294117
# machines[key]['readyTime']: 693.8235294117646
# data[task]['c']: 137.82352941176464
# realy p: 137.8235294117647
#
# task: 47, {'p': 90, 'r': 774, 'c': 0}
# timeCounter: 774
# machines[key]['readyTime']: 693.8235294117646
# machines[key]['readyTime']: 948.7058823529412
# data[task]['c']: 174.70588235294122
# realy p: 174.7058823529412
#
# m: m1
# task: 33, {'p': 60, 'r': 67, 'c': 0}
# timeCounter: 67
# machines[key]['readyTime']: 0
# machines[key]['readyTime']: 181.23076923076923
# data[task]['c']: 114.23076923076923
# realy p: 114.23076923076923
#
# task: 32, {'p': 98, 'r': 230, 'c': 0}
# timeCounter: 230
# machines[key]['readyTime']: 181.23076923076923
# machines[key]['readyTime']: 416.5769230769231
# data[task]['c']: 186.5769230769231
# realy p: 186.57692307692307
#
# task: 30, {'p': 76, 'r': 413, 'c': 0}
# timeCounter: 417
# machines[key]['readyTime']: 416.5769230769231
# machines[key]['readyTime']: 561.6923076923076
# data[task]['c']: 148.69230769230762
# realy p: 144.69230769230768
#
# task: 45, {'p': 52, 'r': 601, 'c': 0}
# timeCounter: 601
# machines[key]['readyTime']: 561.6923076923076
# machines[key]['readyTime']: 700.0
# data[task]['c']: 99.0
# realy p: 98.99999999999999
#
# task: 40, {'p': 92, 'r': 745, 'c': 0}
# timeCounter: 745
# machines[key]['readyTime']: 700.0
# machines[key]['readyTime']: 920.1538461538462
# data[task]['c']: 175.1538461538462
# realy p: 175.15384615384613
#
# m: m2
# task: 31, {'p': 50, 'r': 49, 'c': 0}
# timeCounter: 49
# machines[key]['readyTime']: 0
# machines[key]['readyTime']: 113.28571428571428
# data[task]['c']: 64.28571428571428
# realy p: 64.28571428571428
#
# task: 35, {'p': 36, 'r': 109, 'c': 0}
# timeCounter: 114
# machines[key]['readyTime']: 113.28571428571428
# machines[key]['readyTime']: 160.28571428571428
# data[task]['c']: 51.28571428571428
# realy p: 46.285714285714285
#
# task: 43, {'p': 76, 'r': 197, 'c': 0}
# timeCounter: 197
# machines[key]['readyTime']: 160.28571428571428
# machines[key]['readyTime']: 294.7142857142857
# data[task]['c']: 97.71428571428572
# realy p: 97.71428571428571
#
# task: 10, {'p': 52, 'r': 325, 'c': 0}
# timeCounter: 325
# machines[key]['readyTime']: 294.7142857142857
# machines[key]['readyTime']: 391.8571428571429
# data[task]['c']: 66.85714285714289
# realy p: 66.85714285714286
#
# task: 41, {'p': 43, 'r': 384, 'c': 0}
# timeCounter: 392
# machines[key]['readyTime']: 391.8571428571429
# machines[key]['readyTime']: 447.2857142857143
# data[task]['c']: 63.28571428571428
# realy p: 55.285714285714285
#
# task: 6, {'p': 24, 'r': 467, 'c': 0}
# timeCounter: 467
# machines[key]['readyTime']: 447.2857142857143
# machines[key]['readyTime']: 497.85714285714283
# data[task]['c']: 30.857142857142833
# realy p: 30.857142857142858
#
# task: 44, {'p': 74, 'r': 530, 'c': 0}
# timeCounter: 530
# machines[key]['readyTime']: 497.85714285714283
# machines[key]['readyTime']: 625.1428571428571
# data[task]['c']: 95.14285714285711
# realy p: 95.14285714285714
#
# task: 22, {'p': 36, 'r': 630, 'c': 0}
# timeCounter: 630
# machines[key]['readyTime']: 625.1428571428571
# machines[key]['readyTime']: 676.2857142857143
# data[task]['c']: 46.285714285714334
# realy p: 46.285714285714285
#
# task: 14, {'p': 90, 'r': 680, 'c': 0}
# timeCounter: 680
# machines[key]['readyTime']: 676.2857142857143
# machines[key]['readyTime']: 795.7142857142857
# data[task]['c']: 115.71428571428567
# realy p: 115.71428571428571
#
# task: 27, {'p': 9, 'r': 815, 'c': 0}
# timeCounter: 815
# machines[key]['readyTime']: 795.7142857142857
# machines[key]['readyTime']: 826.5714285714286
# data[task]['c']: 11.571428571428555
# realy p: 11.571428571428571
#
# task: 46, {'p': 83, 'r': 819, 'c': 0}
# timeCounter: 827
# machines[key]['readyTime']: 826.5714285714286
# machines[key]['readyTime']: 933.7142857142857
# data[task]['c']: 114.71428571428567
# realy p: 106.71428571428571
#
# m: m3
# task: 13, {'p': 71, 'r': 29, 'c': 0}
# timeCounter: 29
# machines[key]['readyTime']: 0
# machines[key]['readyTime']: 117.9746835443038
# data[task]['c']: 88.9746835443038
# realy p: 88.9746835443038
#
# task: 20, {'p': 13, 'r': 107, 'c': 0}
# timeCounter: 118
# machines[key]['readyTime']: 117.9746835443038
# machines[key]['readyTime']: 134.29113924050634
# data[task]['c']: 27.29113924050634
# realy p: 16.29113924050633
#
# task: 11, {'p': 13, 'r': 128, 'c': 0}
# timeCounter: 135
# machines[key]['readyTime']: 134.29113924050634
# machines[key]['readyTime']: 151.29113924050634
# data[task]['c']: 23.29113924050634
# realy p: 16.29113924050633
#
# task: 36, {'p': 63, 'r': 176, 'c': 0}
# timeCounter: 176
# machines[key]['readyTime']: 151.29113924050634
# machines[key]['readyTime']: 254.94936708860757
# data[task]['c']: 78.94936708860757
# realy p: 78.94936708860759
#
# task: 23, {'p': 21, 'r': 269, 'c': 0}
# timeCounter: 269
# machines[key]['readyTime']: 254.94936708860757
# machines[key]['readyTime']: 295.3164556962025
# data[task]['c']: 26.316455696202524
# realy p: 26.31645569620253
#
# task: 5, {'p': 50, 'r': 302, 'c': 0}
# timeCounter: 302
# machines[key]['readyTime']: 295.3164556962025
# machines[key]['readyTime']: 364.65822784810126
# data[task]['c']: 62.65822784810126
# realy p: 62.65822784810126
#
# task: 3, {'p': 34, 'r': 376, 'c': 0}
# timeCounter: 376
# machines[key]['readyTime']: 364.65822784810126
# machines[key]['readyTime']: 418.60759493670884
# data[task]['c']: 42.607594936708836
# realy p: 42.60759493670886
#
# task: 17, {'p': 43, 'r': 434, 'c': 0}
# timeCounter: 434
# machines[key]['readyTime']: 418.60759493670884
# machines[key]['readyTime']: 487.88607594936707
# data[task]['c']: 53.88607594936707
# realy p: 53.88607594936709
#
# task: 48, {'p': 97, 'r': 487, 'c': 0}
# timeCounter: 488
# machines[key]['readyTime']: 487.88607594936707
# machines[key]['readyTime']: 609.5569620253165
# data[task]['c']: 122.55696202531647
# realy p: 121.55696202531645
#
# task: 49, {'p': 27, 'r': 617, 'c': 0}
# timeCounter: 617
# machines[key]['readyTime']: 609.5569620253165
# machines[key]['readyTime']: 650.8354430379746
# data[task]['c']: 33.83544303797464
# realy p: 33.835443037974684
#
# task: 50, {'p': 27, 'r': 671, 'c': 0}
# timeCounter: 671
# machines[key]['readyTime']: 650.8354430379746
# machines[key]['readyTime']: 704.8354430379746
# data[task]['c']: 33.83544303797464
# realy p: 33.835443037974684
#
# task: 1, {'p': 92, 'r': 713, 'c': 0}
# timeCounter: 713
# machines[key]['readyTime']: 704.8354430379746
# machines[key]['readyTime']: 828.2911392405064
# data[task]['c']: 115.29113924050637
# realy p: 115.29113924050633
#
# m: m4
# task: 28, {'p': 89, 'r': 0, 'c': 0}
# timeCounter: 0
# machines[key]['readyTime']: 0
# machines[key]['readyTime']: 89.0
# data[task]['c']: 89.0
# realy p: 89.0
#
# task: 39, {'p': 31, 'r': 97, 'c': 0}
# timeCounter: 97
# machines[key]['readyTime']: 89.0
# machines[key]['readyTime']: 128.0
# data[task]['c']: 31.0
# realy p: 31.0
#
# task: 19, {'p': 24, 'r': 125, 'c': 0}
# timeCounter: 128
# machines[key]['readyTime']: 128.0
# machines[key]['readyTime']: 152.0
# data[task]['c']: 27.0
# realy p: 24.0
#
# task: 37, {'p': 52, 'r': 153, 'c': 0}
# timeCounter: 153
# machines[key]['readyTime']: 152.0
# machines[key]['readyTime']: 205.0
# data[task]['c']: 52.0
# realy p: 52.0
#
# task: 34, {'p': 32, 'r': 216, 'c': 0}
# timeCounter: 216
# machines[key]['readyTime']: 205.0
# machines[key]['readyTime']: 248.0
# data[task]['c']: 32.0
# realy p: 32.0
#
# task: 16, {'p': 24, 'r': 264, 'c': 0}
# timeCounter: 264
# machines[key]['readyTime']: 248.0
# machines[key]['readyTime']: 288.0
# data[task]['c']: 24.0
# realy p: 24.0
#
# task: 42, {'p': 8, 'r': 300, 'c': 0}
# timeCounter: 300
# machines[key]['readyTime']: 288.0
# machines[key]['readyTime']: 308.0
# data[task]['c']: 8.0
# realy p: 8.0
#
# task: 18, {'p': 35, 'r': 313, 'c': 0}
# timeCounter: 313
# machines[key]['readyTime']: 308.0
# machines[key]['readyTime']: 348.0
# data[task]['c']: 35.0
# realy p: 35.0
#
# task: 25, {'p': 93, 'r': 346, 'c': 0}
# timeCounter: 348
# machines[key]['readyTime']: 348.0
# machines[key]['readyTime']: 441.0
# data[task]['c']: 95.0
# realy p: 93.0
#
# task: 12, {'p': 60, 'r': 450, 'c': 0}
# timeCounter: 450
# machines[key]['readyTime']: 441.0
# machines[key]['readyTime']: 510.0
# data[task]['c']: 60.0
# realy p: 60.0
#
# task: 7, {'p': 38, 'r': 523, 'c': 0}
# timeCounter: 523
# machines[key]['readyTime']: 510.0
# machines[key]['readyTime']: 561.0
# data[task]['c']: 38.0
# realy p: 38.0
#
# task: 26, {'p': 71, 'r': 579, 'c': 0}
# timeCounter: 579
# machines[key]['readyTime']: 561.0
# machines[key]['readyTime']: 650.0
# data[task]['c']: 71.0
# realy p: 71.0
#
# task: 9, {'p': 97, 'r': 642, 'c': 0}
# timeCounter: 650
# machines[key]['readyTime']: 650.0
# machines[key]['readyTime']: 747.0
# data[task]['c']: 105.0
# realy p: 97.0
#
# task: 8, {'p': 4, 'r': 773, 'c': 0}
# timeCounter: 773
# machines[key]['readyTime']: 747.0
# machines[key]['readyTime']: 777.0
# data[task]['c']: 4.0
# realy p: 4.0
#
# task: 15, {'p': 35, 'r': 803, 'c': 0}
# timeCounter: 803
# machines[key]['readyTime']: 777.0
# machines[key]['readyTime']: 838.0
# data[task]['c']: 35.0
# realy p: 35.0
#
# 1 -> {'p': 92, 'r': 713, 'c': 115.29113924050637}
# 2 -> {'p': 67, 'r': 137, 'c': 137.05882352941177}
# 3 -> {'p': 34, 'r': 376, 'c': 42.607594936708836}
# 4 -> {'p': 71, 'r': 556, 'c': 137.82352941176464}
# 5 -> {'p': 50, 'r': 302, 'c': 62.65822784810126}
# 6 -> {'p': 24, 'r': 467, 'c': 30.857142857142833}
# 7 -> {'p': 38, 'r': 523, 'c': 38.0}
# 8 -> {'p': 4, 'r': 773, 'c': 4.0}
# 9 -> {'p': 97, 'r': 642, 'c': 105.0}
# 10 -> {'p': 52, 'r': 325, 'c': 66.85714285714289}
# 11 -> {'p': 13, 'r': 128, 'c': 23.29113924050634}
# 12 -> {'p': 60, 'r': 450, 'c': 60.0}
# 13 -> {'p': 71, 'r': 29, 'c': 88.9746835443038}
# 14 -> {'p': 90, 'r': 680, 'c': 115.71428571428567}
# 15 -> {'p': 35, 'r': 803, 'c': 35.0}
# 16 -> {'p': 24, 'r': 264, 'c': 24.0}
# 17 -> {'p': 43, 'r': 434, 'c': 53.88607594936707}
# 18 -> {'p': 35, 'r': 313, 'c': 35.0}
# 19 -> {'p': 24, 'r': 125, 'c': 27.0}
# 20 -> {'p': 13, 'r': 107, 'c': 27.29113924050634}
# 21 -> {'p': 31, 'r': 83, 'c': 60.176470588235304}
# 22 -> {'p': 36, 'r': 630, 'c': 46.285714285714334}
# 23 -> {'p': 21, 'r': 269, 'c': 26.316455696202524}
# 24 -> {'p': 33, 'r': 480, 'c': 64.05882352941171}
# 25 -> {'p': 93, 'r': 346, 'c': 95.0}
# 26 -> {'p': 71, 'r': 579, 'c': 71.0}
# 27 -> {'p': 9, 'r': 815, 'c': 11.571428571428555}
# 28 -> {'p': 89, 'r': 0, 'c': 89.0}
# 29 -> {'p': 65, 'r': 274, 'c': 127.1764705882353}
# 30 -> {'p': 76, 'r': 413, 'c': 148.69230769230762}
# 31 -> {'p': 50, 'r': 49, 'c': 64.28571428571428}
# 32 -> {'p': 98, 'r': 230, 'c': 186.5769230769231}
# 33 -> {'p': 60, 'r': 67, 'c': 114.23076923076923}
# 34 -> {'p': 32, 'r': 216, 'c': 32.0}
# 35 -> {'p': 36, 'r': 109, 'c': 51.28571428571428}
# 36 -> {'p': 63, 'r': 176, 'c': 78.94936708860757}
# 37 -> {'p': 52, 'r': 153, 'c': 52.0}
# 38 -> {'p': 37, 'r': 402, 'c': 71.8235294117647}
# 39 -> {'p': 31, 'r': 97, 'c': 31.0}
# 40 -> {'p': 92, 'r': 745, 'c': 175.1538461538462}
# 41 -> {'p': 43, 'r': 384, 'c': 63.28571428571428}
# 42 -> {'p': 8, 'r': 300, 'c': 8.0}
# 43 -> {'p': 76, 'r': 197, 'c': 97.71428571428572}
# 44 -> {'p': 74, 'r': 530, 'c': 95.14285714285711}
# 45 -> {'p': 52, 'r': 601, 'c': 99.0}
# 46 -> {'p': 83, 'r': 819, 'c': 114.71428571428567}
# 47 -> {'p': 90, 'r': 774, 'c': 174.70588235294122}
# 48 -> {'p': 97, 'r': 487, 'c': 122.55696202531647}
# 49 -> {'p': 27, 'r': 617, 'c': 33.83544303797464}
# 50 -> {'p': 27, 'r': 671, 'c': 33.83544303797464}
# Error
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-f2e7d143a5d0> in <module>
#      26                 data[i+1] = {"p": p, "r": r, "c": 0 }
#      27
# ---> 28         calculatedWeight = calculateCost(data, taskQueue, machines)
#      29         print(calculatedWeight)
#      30         #if calculatedWeight != weight:
#
# <ipython-input-103-4ab939e0baba> in calculateCost(data, taskQueue, machines)
#      35
#      36     # verify cost
# ---> 37     if data[task]["c"] > data[task]["d"]:
#      38         calculatedWeight += data[task]["w"]
#      39     #print(calculatedWeight)
#
# KeyError: 'd'

# %%
machines
# Out:
# {'m0': {'speed': '0.9583333333333334', 'readyTime': 0},
#  'm1': {'speed': '0.5729166666666666', 'readyTime': 0},
#  'm2': {'speed': '0.010416666666666666', 'readyTime': 0},
#  'm3': {'speed': '1.0', 'readyTime': 0},
#  'm4': {'speed': '0.20833333333333334', 'readyTime': 0}}

# %%
# p - persistance
# r - ready time
# d - oczekiwany termin zakończenia
# w - weight
# Cj oznacza moment zakończenia wykonywania zadania Jj w uszeregowaniu

# p r d w
# r  >= c - p

# %% [markdown]
# # TaskScheduler

# %%
a,b,c,d = (1,1,1,1)
totalCost = 0
data = {}

indicies = ['136723']#["136805", "136792", "136683", "132231", "136730", "136682", "136764", "136782", "136723", "136778", "136309", "136718", "136315", "136759"]
for index  in indicies:
    for samples in nSamples:
        with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
            d = instance.read().split('\n')
            n = int(d[0])
            machines = {}
            for name, speed in zip(machineNames, d[1].split(' ')):
                machines[name] = {'speed':speed, 'readyTime':0, 'gain':0}
            for i,line in enumerate(d[2:]):
                if line == '':
                    continue
                p,r = line.split(' ')
                p,r = int(p), int(r)
                data[i+1] = {"p": p, "r": r, "c": 0, "penalty": 0 }
            dataCopy = copy.deepcopy(data)
        
        calculatedWeight = 0
        timeCounter = 0
        outSchedule = {}
        for name in machineNames:
            outSchedule[name] = []
        
        start = time.time()
        while len(data) > 0:
            readyToGo = {}
            for key, task in data.items():
                if task['r'] <= timeCounter: # add penalty ( (timeCounter+p-d)*w )
                    endTime = timeCounter+task['p']
                    penaltyEndTask = ( endTime if endTime > 0 else 0 ) * 1
                    penaltyPersistance = task['p']
                    task['penalty'] = a*penaltyEndTask + c*penaltyPersistance
                    readyToGo[key] = task
                
            if len(readyToGo) == 0: # currently there is no task to go
                #print("upsi readyToGo")
                timeCounter += 1
                continue
            #print(f"readyToGo: {readyToGo}")

            # select task
            readyToGoSorted = sorted(readyToGo.items(), key=lambda y: (y[1]['penalty']), reverse=True)
            selectedTask = readyToGoSorted[0]
            
            # select machine
            readyMachines = [d for d in zip(machines.keys(), machines.values() ) if d[1]['readyTime'] <= timeCounter]
            if len(readyMachines) == 0: # currently there is free machine
                #print("upsi readyMachines")
                timeCounter += 1
                continue
            
            
            for name, machine in machines.values():
                howLongItWillBeDisabled = 0 ##########################################
                speed = machines[name]['speed']
                
                machines[name]['gain'] = speed
            selectedMachine = max(readyMachines, key=lambda y: (y[1]['speed']))
            
            print(f"timeCounter: {timeCounter}")
            print(f"selectedTask: {selectedTask}")
            
            # remove task from list active tasks, add time, append outschedule
            data.pop(selectedTask[0])
            
            print(f"selectedMachine: {selectedMachine}")
            #timeCounter += 1
            machines[selectedMachine[0]]['readyTime'] = timeCounter + (selectedTask[1]['p'] / float(selectedMachine[1]['speed']) )
            print(machines)
            
            print()
            
            outSchedule[selectedMachine[0]].append(selectedTask[0])    
        
        end = time.time()
        #print(end-start)
        
        #cost = calculateCost(dataCopy, outSchedule)
        cost = 5
        #print(cost)
        totalCost += cost
        
        print(outSchedule)
        
        with open(f'out/{index}/out{index}_{samples}.txt', "w") as f:
            f.write(f"{cost}\n")         
                #f.write(f"{' '.join([str(x) for x in line])}\n")
            for name in machineNames:
                f.write(f"{' '.join([str(x) for x in outSchedule[name]])}\n")
        
        break
        
print(totalCost)
# Out:
# timeCounter: 0
# selectedTask: (28, {'p': 89, 'r': 0, 'c': 0, 'penalty': 178})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 0}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 0}, 'm3': {'speed': '0.797979797979798', 'readyTime': 0}, 'm4': {'speed': '1.0', 'readyTime': 89.0}}
#
# timeCounter: 29
# selectedTask: (13, {'p': 71, 'r': 29, 'c': 0, 'penalty': 171})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 0}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 0}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 89.0}}
#
# timeCounter: 49
# selectedTask: (31, {'p': 50, 'r': 49, 'c': 0, 'penalty': 149})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 0}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 113.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 89.0}}
#
# timeCounter: 67
# selectedTask: (33, {'p': 60, 'r': 67, 'c': 0, 'penalty': 187})
# selectedMachine: ('m1', {'speed': '0.5252525252525253', 'readyTime': 0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 0}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 113.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 89.0}}
#
# timeCounter: 83
# selectedTask: (21, {'p': 31, 'r': 83, 'c': 0, 'penalty': 145})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 113.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 89.0}}
#
# timeCounter: 97
# selectedTask: (39, {'p': 31, 'r': 97, 'c': 0, 'penalty': 159})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 89.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 113.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 128.0}}
#
# timeCounter: 114
# selectedTask: (35, {'p': 36, 'r': 109, 'c': 0, 'penalty': 186})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 113.28571428571428})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 117.9746835443038}, 'm4': {'speed': '1.0', 'readyTime': 128.0}}
#
# timeCounter: 118
# selectedTask: (20, {'p': 13, 'r': 107, 'c': 0, 'penalty': 144})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 117.9746835443038})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 134.29113924050634}, 'm4': {'speed': '1.0', 'readyTime': 128.0}}
#
# timeCounter: 128
# selectedTask: (19, {'p': 24, 'r': 125, 'c': 0, 'penalty': 176})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 128.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 134.29113924050634}, 'm4': {'speed': '1.0', 'readyTime': 152.0}}
#
# timeCounter: 135
# selectedTask: (11, {'p': 13, 'r': 128, 'c': 0, 'penalty': 161})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 134.29113924050634})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 151.29113924050634}, 'm4': {'speed': '1.0', 'readyTime': 152.0}}
#
# timeCounter: 144
# selectedTask: (2, {'p': 67, 'r': 137, 'c': 0, 'penalty': 278})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 143.1764705882353})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 151.29113924050634}, 'm4': {'speed': '1.0', 'readyTime': 152.0}}
#
# timeCounter: 153
# selectedTask: (37, {'p': 52, 'r': 153, 'c': 0, 'penalty': 257})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 152.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 151.29113924050634}, 'm4': {'speed': '1.0', 'readyTime': 205.0}}
#
# timeCounter: 176
# selectedTask: (36, {'p': 63, 'r': 176, 'c': 0, 'penalty': 302})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 151.29113924050634})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428}, 'm3': {'speed': '0.797979797979798', 'readyTime': 254.94936708860757}, 'm4': {'speed': '1.0', 'readyTime': 205.0}}
#
# timeCounter: 197
# selectedTask: (43, {'p': 76, 'r': 197, 'c': 0, 'penalty': 349})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 160.28571428571428})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 254.94936708860757}, 'm4': {'speed': '1.0', 'readyTime': 205.0}}
#
# timeCounter: 216
# selectedTask: (34, {'p': 32, 'r': 216, 'c': 0, 'penalty': 280})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 205.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 254.94936708860757}, 'm4': {'speed': '1.0', 'readyTime': 248.0}}
#
# timeCounter: 230
# selectedTask: (32, {'p': 98, 'r': 230, 'c': 0, 'penalty': 426})
# selectedMachine: ('m1', {'speed': '0.5252525252525253', 'readyTime': 181.23076923076923})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 254.94936708860757}, 'm4': {'speed': '1.0', 'readyTime': 248.0}}
#
# timeCounter: 264
# selectedTask: (16, {'p': 24, 'r': 264, 'c': 0, 'penalty': 312})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 248.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 254.94936708860757}, 'm4': {'speed': '1.0', 'readyTime': 288.0}}
#
# timeCounter: 269
# selectedTask: (23, {'p': 21, 'r': 269, 'c': 0, 'penalty': 311})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 254.94936708860757})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 295.3164556962025}, 'm4': {'speed': '1.0', 'readyTime': 288.0}}
#
# timeCounter: 275
# selectedTask: (29, {'p': 65, 'r': 274, 'c': 0, 'penalty': 405})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 274.05882352941177})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 295.3164556962025}, 'm4': {'speed': '1.0', 'readyTime': 288.0}}
#
# timeCounter: 300
# selectedTask: (42, {'p': 8, 'r': 300, 'c': 0, 'penalty': 316})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 288.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 295.3164556962025}, 'm4': {'speed': '1.0', 'readyTime': 308.0}}
#
# timeCounter: 302
# selectedTask: (5, {'p': 50, 'r': 302, 'c': 0, 'penalty': 402})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 295.3164556962025})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 364.65822784810126}, 'm4': {'speed': '1.0', 'readyTime': 308.0}}
#
# timeCounter: 313
# selectedTask: (18, {'p': 35, 'r': 313, 'c': 0, 'penalty': 383})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 308.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 364.65822784810126}, 'm4': {'speed': '1.0', 'readyTime': 348.0}}
#
# timeCounter: 325
# selectedTask: (10, {'p': 52, 'r': 325, 'c': 0, 'penalty': 429})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 294.7142857142857})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 391.8571428571429}, 'm3': {'speed': '0.797979797979798', 'readyTime': 364.65822784810126}, 'm4': {'speed': '1.0', 'readyTime': 348.0}}
#
# timeCounter: 348
# selectedTask: (25, {'p': 93, 'r': 346, 'c': 0, 'penalty': 534})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 348.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 391.8571428571429}, 'm3': {'speed': '0.797979797979798', 'readyTime': 364.65822784810126}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 376
# selectedTask: (3, {'p': 34, 'r': 376, 'c': 0, 'penalty': 444})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 364.65822784810126})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 391.8571428571429}, 'm3': {'speed': '0.797979797979798', 'readyTime': 418.60759493670884}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 392
# selectedTask: (41, {'p': 43, 'r': 384, 'c': 0, 'penalty': 478})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 391.8571428571429})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 418.60759493670884}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 402
# selectedTask: (38, {'p': 37, 'r': 402, 'c': 0, 'penalty': 476})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 401.1764705882353})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 418.60759493670884}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 417
# selectedTask: (30, {'p': 76, 'r': 413, 'c': 0, 'penalty': 569})
# selectedMachine: ('m1', {'speed': '0.5252525252525253', 'readyTime': 416.5769230769231})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 418.60759493670884}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 434
# selectedTask: (17, {'p': 43, 'r': 434, 'c': 0, 'penalty': 520})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 418.60759493670884})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 487.88607594936707}, 'm4': {'speed': '1.0', 'readyTime': 441.0}}
#
# timeCounter: 450
# selectedTask: (12, {'p': 60, 'r': 450, 'c': 0, 'penalty': 570})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 441.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 487.88607594936707}, 'm4': {'speed': '1.0', 'readyTime': 510.0}}
#
# timeCounter: 467
# selectedTask: (6, {'p': 24, 'r': 467, 'c': 0, 'penalty': 515})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 447.2857142857143})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 497.85714285714283}, 'm3': {'speed': '0.797979797979798', 'readyTime': 487.88607594936707}, 'm4': {'speed': '1.0', 'readyTime': 510.0}}
#
# timeCounter: 480
# selectedTask: (24, {'p': 33, 'r': 480, 'c': 0, 'penalty': 546})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 473.8235294117647})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 544.0588235294117}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 497.85714285714283}, 'm3': {'speed': '0.797979797979798', 'readyTime': 487.88607594936707}, 'm4': {'speed': '1.0', 'readyTime': 510.0}}
#
# timeCounter: 488
# selectedTask: (48, {'p': 97, 'r': 487, 'c': 0, 'penalty': 682})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 487.88607594936707})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 544.0588235294117}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 497.85714285714283}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 510.0}}
#
# timeCounter: 523
# selectedTask: (7, {'p': 38, 'r': 523, 'c': 0, 'penalty': 599})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 510.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 544.0588235294117}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 497.85714285714283}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 561.0}}
#
# timeCounter: 530
# selectedTask: (44, {'p': 74, 'r': 530, 'c': 0, 'penalty': 678})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 497.85714285714283})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 544.0588235294117}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 561.0}}
#
# timeCounter: 556
# selectedTask: (4, {'p': 71, 'r': 556, 'c': 0, 'penalty': 698})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 544.0588235294117})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 561.0}}
#
# timeCounter: 579
# selectedTask: (26, {'p': 71, 'r': 579, 'c': 0, 'penalty': 721})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 561.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 650.0}}
#
# timeCounter: 601
# selectedTask: (45, {'p': 52, 'r': 601, 'c': 0, 'penalty': 705})
# selectedMachine: ('m1', {'speed': '0.5252525252525253', 'readyTime': 561.6923076923076})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571}, 'm3': {'speed': '0.797979797979798', 'readyTime': 609.5569620253165}, 'm4': {'speed': '1.0', 'readyTime': 650.0}}
#
# timeCounter: 617
# selectedTask: (49, {'p': 27, 'r': 617, 'c': 0, 'penalty': 671})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 609.5569620253165})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571}, 'm3': {'speed': '0.797979797979798', 'readyTime': 650.8354430379746}, 'm4': {'speed': '1.0', 'readyTime': 650.0}}
#
# timeCounter: 630
# selectedTask: (22, {'p': 36, 'r': 630, 'c': 0, 'penalty': 702})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 625.1428571428571})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 676.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 650.8354430379746}, 'm4': {'speed': '1.0', 'readyTime': 650.0}}
#
# timeCounter: 650
# selectedTask: (9, {'p': 97, 'r': 642, 'c': 0, 'penalty': 844})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 650.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 676.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 650.8354430379746}, 'm4': {'speed': '1.0', 'readyTime': 747.0}}
#
# timeCounter: 671
# selectedTask: (50, {'p': 27, 'r': 671, 'c': 0, 'penalty': 725})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 650.8354430379746})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 676.2857142857143}, 'm3': {'speed': '0.797979797979798', 'readyTime': 704.8354430379746}, 'm4': {'speed': '1.0', 'readyTime': 747.0}}
#
# timeCounter: 680
# selectedTask: (14, {'p': 90, 'r': 680, 'c': 0, 'penalty': 860})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 676.2857142857143})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 704.8354430379746}, 'm4': {'speed': '1.0', 'readyTime': 747.0}}
#
# timeCounter: 713
# selectedTask: (1, {'p': 92, 'r': 713, 'c': 0, 'penalty': 897})
# selectedMachine: ('m3', {'speed': '0.797979797979798', 'readyTime': 704.8354430379746})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 700.0}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 747.0}}
#
# timeCounter: 745
# selectedTask: (40, {'p': 92, 'r': 745, 'c': 0, 'penalty': 929})
# selectedMachine: ('m1', {'speed': '0.5252525252525253', 'readyTime': 700.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 747.0}}
#
# timeCounter: 773
# selectedTask: (8, {'p': 4, 'r': 773, 'c': 0, 'penalty': 781})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 747.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 777.0}}
#
# timeCounter: 774
# selectedTask: (47, {'p': 90, 'r': 774, 'c': 0, 'penalty': 954})
# selectedMachine: ('m0', {'speed': '0.5151515151515151', 'readyTime': 693.8235294117646})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 948.7058823529412}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 777.0}}
#
# timeCounter: 803
# selectedTask: (15, {'p': 35, 'r': 803, 'c': 0, 'penalty': 873})
# selectedMachine: ('m4', {'speed': '1.0', 'readyTime': 777.0})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 948.7058823529412}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 838.0}}
#
# timeCounter: 815
# selectedTask: (27, {'p': 9, 'r': 815, 'c': 0, 'penalty': 833})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 795.7142857142857})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 948.7058823529412}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 826.5714285714286}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 838.0}}
#
# timeCounter: 827
# selectedTask: (46, {'p': 83, 'r': 819, 'c': 0, 'penalty': 993})
# selectedMachine: ('m2', {'speed': '0.7777777777777778', 'readyTime': 826.5714285714286})
# {'m0': {'speed': '0.5151515151515151', 'readyTime': 948.7058823529412}, 'm1': {'speed': '0.5252525252525253', 'readyTime': 920.1538461538462}, 'm2': {'speed': '0.7777777777777778', 'readyTime': 933.7142857142857}, 'm3': {'speed': '0.797979797979798', 'readyTime': 828.2911392405064}, 'm4': {'speed': '1.0', 'readyTime': 838.0}}
#
# {'m0': [21, 2, 29, 38, 24, 4, 47], 'm1': [33, 32, 30, 45, 40], 'm2': [31, 35, 43, 10, 41, 6, 44, 22, 14, 27, 46], 'm3': [13, 20, 11, 36, 23, 5, 3, 17, 48, 49, 50, 1], 'm4': [28, 39, 19, 37, 34, 16, 42, 18, 25, 12, 7, 26, 9, 8, 15]}
# 5

# %%
x = {'m0':{'speed':2, 'readyTime':0},'m1':{'speed':3, 'readyTime':0},'m2':{'speed':1, 'readyTime':5}, }

# %%
zip(machines.keys(), machines.values() )

# %%
[d for d in x.values() if d['readyTime'] <= 0]
# Out:
# [{'speed': 2, 'readyTime': 0}, {'speed': 3, 'readyTime': 0}]

# %%
readyMachines = [d for d in x.values() if d['readyTime'] <= 0]
readyMachines = max(readyMachines, key=lambda y: (y['speed']))
readyMachines
# Out:
# {'speed': 3, 'readyTime': 0}

# %%
from scipy.optimize import minimize

# %%
x0 = (1, 1, 1, 1)

# %%
def costFunction(x):
    a,b,c,d = x
    totalCost = 0
    data = {}
    indicies = ["136805", "136792", "136683", "132231", "136730", "136682", "136764", "136782", "136723", "136778", "136309", "136718", "136315", "136759"]
    for index  in indicies:
        for samples in nSamples:
            with open(f'PTSZ-instancje/{index}/in{index}_{samples}.txt', "r") as instance:
                d = instance.read().split('\n')
                n = int(d[0])                
                for i,line in enumerate(d[1:]):
                    if line == '':
                        continue
                    p,r,d,w = line.split(' ')
                    p,r,d,w = int(p), int(r), int(d), int(w)
                    data[i+1] = {"p": p, "r": r, "d": d, "w": w, "c": 0, "penalty": 0 }
                dataCopy = copy.deepcopy(data)


            calculatedWeight = 0
            timeCounter = 0
            outSchedule = []

            start = time.time()
            while len(data) > 0:
                readyToGo = {}
                for key, task in data.items():
                    if task['r'] <= timeCounter: # add penalty ( (timeCounter+p-d)*w )
                        endTime = timeCounter+task['p']-task['d']
                        penaltyEndTask = ( endTime if endTime > 0 else 0 ) * task['w']
                        penaltyWeight = task['w']
                        penaltyPersistance = task['p']
                        penaltyDue = task['d'] - timeCounter
                        task['penalty'] = a*penaltyEndTask + b*penaltyWeight + c*penaltyPersistance - d*penaltyDue
                        readyToGo[key] = task

                if len(readyToGo) == 0: # currently there is no task to go
                    #print("upsi")
                    timeCounter += 1
                    continue
                #print(f"readyToGo: {readyToGo}")

                readyToGoSorted = sorted(readyToGo.items(), key=lambda y: (y[1]['penalty'], y[1]['w']), reverse=True)
                selectedTask = readyToGoSorted.pop(0)
                #print(timeCounter)
                #print(f"selectedTask: {selectedTask}")

                data.pop(selectedTask[0])
                timeCounter += selectedTask[1]['p']
                outSchedule.append(selectedTask[0])    

            end = time.time()
          #  print(int((end-start)*1000) if int((end-start)*1000) != 0 else 1)

            cost = calculateCost(dataCopy, outSchedule)
            #print(cost)
            totalCost += cost
    print(f"[{totalCost},{a},{b},{c},{d}],")
    return totalCost

# %%
options = {"maxiter":40, "disp":True}

# %%
res = minimize(costFunction, x0, method='TNC', options=options, tol=1e-2)
# Out:
# [499007,1.0,1.0,1.0,1183],
# [499007,1.0,1.0,1.0,1183],
# [499012,1.00000001,1.0,1.0,1183],
# [499007,1.0,1.00000001,1.0,1183],
# [499030,1.0,1.0,1.00000001,1183],
# [499007,1.0,1.0,1.0,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,1.0000000036691032,1.0,0.999999970877875,1183],
# [499007,0.9999999936691033,1.00000001,0.999999970877875,1183],
# [499007,0.9999999936691033,1.0,0.999999980877875,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,1.0000000036691032,1.0,0.999999970877875,1183],
# [499007,0.9999999936691033,1.00000001,0.999999970877875,1183],
# [499007,0.9999999936691033,1.0,0.999999980877875,1183],
# [499007,0.9999999936691033,1.0,0.999999970877875,1183],
# [499007,0.9999999968345517,1.0,0.9999999854389375,1183],
# [499007,0.9999999968345517,1.0,0.9999999854389375,1183],
# [499007,1.0000000068345516,1.0,0.9999999854389375,1183],
# [499007,0.9999999968345517,1.00000001,0.9999999854389375,1183],
# [499007,0.9999999968345517,1.0,0.9999999954389376,1183],
# [499007,0.9999999968345517,1.0,0.9999999854389375,1183],
# [499007,0.9999999984172758,1.0,0.9999999927194687,1183],
# [499007,0.9999999984172758,1.0,0.9999999927194687,1183],
# [499012,1.0000000084172758,1.0,0.9999999927194687,1183],
# [499007,0.9999999984172758,1.00000001,0.9999999927194687,1183],
# [499025,0.9999999984172758,1.0,1.0000000027194687,1183],
# [499007,0.9999999984172758,1.0,0.9999999927194687,1183],
# [499007,0.9999999992086379,1.0,0.9999999963597344,1183],
# [499007,0.9999999992086379,1.0,0.9999999963597344,1183],
# [499012,1.0000000092086379,1.0,0.9999999963597344,1183],
# [499007,0.9999999992086379,1.00000001,0.9999999963597344,1183],
# [499030,0.9999999992086379,1.0,1.0000000063597343,1183],
# [499007,0.9999999992086379,1.0,0.9999999963597344,1183],
# [499007,0.999999999604319,1.0,0.9999999981798672,1183],
# [499007,0.999999999604319,1.0,0.9999999981798672,1183],
# [499012,1.000000009604319,1.0,0.9999999981798672,1183],
# [499007,0.999999999604319,1.00000001,0.9999999981798672,1183],
# [499030,0.999999999604319,1.0,1.0000000081798672,1183],
# [499007,0.999999999604319,1.0,0.9999999981798672,1183],
# [499007,0.9999999998021595,1.0,0.9999999990899336,1183],
# [499007,0.9999999998021595,1.0,0.9999999990899336,1183],
# [499012,1.0000000098021595,1.0,0.9999999990899336,1183],
# [499007,0.9999999998021595,1.00000001,0.9999999990899336,1183],
# [499030,0.9999999998021595,1.0,1.0000000090899337,1183],
# [499007,0.9999999998021595,1.0,0.9999999990899336,1183],
# [499007,0.9999999999010797,1.0,0.9999999995449668,1183],
# [499007,0.9999999999010797,1.0,0.9999999995449668,1183],
# [499012,1.0000000099010797,1.0,0.9999999995449668,1183],
# [499007,0.9999999999010797,1.00000001,0.9999999995449668,1183],
# [499030,0.9999999999010797,1.0,1.0000000095449668,1183],
# [499007,0.9999999999010797,1.0,0.9999999995449668,1183],
# [499007,0.9999999999505399,1.0,0.9999999997724834,1183],
# [499007,0.9999999999505399,1.0,0.9999999997724834,1183],
# [499012,1.00000000995054,1.0,0.9999999997724834,1183],
# [499007,0.9999999999505399,1.00000001,0.9999999997724834,1183],
# [499030,0.9999999999505399,1.0,1.0000000097724835,1183],
# [499007,0.9999999999505399,1.0,0.9999999997724834,1183],
# [499007,0.9999999999752699,1.0,0.9999999998862417,1183],
# [499007,0.9999999999752699,1.0,0.9999999998862417,1183],
# [499012,1.00000000997527,1.0,0.9999999998862417,1183],
# [499007,0.9999999999752699,1.00000001,0.9999999998862417,1183],
# [499030,0.9999999999752699,1.0,1.0000000098862416,1183],
# [499007,0.9999999999752699,1.0,0.9999999998862417,1183],
# [499007,0.999999999987635,1.0,0.9999999999431208,1183],
# [499007,0.999999999987635,1.0,0.9999999999431208,1183],
# [499012,1.000000009987635,1.0,0.9999999999431208,1183],
# [499007,0.999999999987635,1.00000001,0.9999999999431208,1183],
# [499030,0.999999999987635,1.0,1.0000000099431208,1183],
# [499007,0.999999999987635,1.0,0.9999999999431208,1183],
# [499007,0.9999999999938175,1.0,0.9999999999715604,1183],
# [499007,0.9999999999938175,1.0,0.9999999999715604,1183],
# [499012,1.0000000099938176,1.0,0.9999999999715604,1183],
# [499007,0.9999999999938175,1.00000001,0.9999999999715604,1183],
# [499030,0.9999999999938175,1.0,1.0000000099715605,1183],
# [499007,0.9999999999938175,1.0,0.9999999999715604,1183],
# [499007,0.9999999999969087,1.0,0.9999999999857803,1183],
# [499007,0.9999999999969087,1.0,0.9999999999857803,1183],
# [499012,1.0000000099969086,1.0,0.9999999999857803,1183],
# [499007,0.9999999999969087,1.00000001,0.9999999999857803,1183],
# [499030,0.9999999999969087,1.0,1.0000000099857802,1183],
# [499007,0.9999999999969087,1.0,0.9999999999857803,1183],
# [499007,0.9999999999984543,1.0,0.9999999999928901,1183],
# [499007,0.9999999999984543,1.0,0.9999999999928901,1183],
# [499012,1.0000000099984543,1.0,0.9999999999928901,1183],
# [499007,0.9999999999984543,1.00000001,0.9999999999928901,1183],
# [499030,0.9999999999984543,1.0,1.00000000999289,1183],
# [499007,0.9999999999984543,1.0,0.9999999999928901,1183],
# [499007,0.9999999999992272,1.0,0.9999999999964451,1183],
# [499007,0.9999999999992272,1.0,0.9999999999964451,1183],
# [499012,1.0000000099992272,1.0,0.9999999999964451,1183],
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b3e810c300d9> in <module>
# ----> 1 res = minimize(costFunction, x0, method='TNC', options=options, tol=1e-2)
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
# --> 613                              **options)
#     614     elif meth == 'cobyla':
#     615         return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/tnc.py in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, **unknown_options)
#     407                                         offset, messages, maxCGit, maxfun,
#     408                                         eta, stepmx, accuracy, fmin, ftol,
# --> 409                                         xtol, pgtol, rescale, callback)
#     410
#     411     funv, jacv = func_and_grad(x)
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/tnc.py in func_and_grad(x)
#     365         def func_and_grad(x):
#     366             f = fun(x, *args)
# --> 367             g = approx_fprime(x, fun, epsilon, *args)
#     368             return f, g
#     369     else:
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in approx_fprime(xk, f, epsilon, *args)
#     763
#     764     """
# --> 765     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     766
#     767
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     695         ei[k] = 1.0
#     696         d = epsilon * ei
# --> 697         df = (f(*((xk + d,) + args)) - f0) / d[k]
#     698         if not np.isscalar(df):
#     699             try:
#
# <ipython-input-17-f8f55bbbf6a3> in costFunction(x)
#      41                 #print(f"readyToGo: {readyToGo}")
#      42
# ---> 43                 readyToGoSorted = sorted(readyToGo.items(), key=lambda y: (y[1]['penalty'], y[1]['w']), reverse=True)
#      44                 selectedTask = readyToGoSorted.pop(0)
#      45                 #print(timeCounter)
#
# <ipython-input-17-f8f55bbbf6a3> in <lambda>(y)
#      41                 #print(f"readyToGo: {readyToGo}")
#      42
# ---> 43                 readyToGoSorted = sorted(readyToGo.items(), key=lambda y: (y[1]['penalty'], y[1]['w']), reverse=True)
#      44                 selectedTask = readyToGoSorted.pop(0)
#      45                 #print(timeCounter)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]

# %%
plt.plot(x)
plt.title("Minimalizacja funkcji celu")
plt.xaxis("iteracja")
plt.yaxis("Koszt")

# %%
costFunction(x)
# Out:
# 1
# 7
# 13
# 25
# 17
# 19
# 26
# 33
# 38
# 61
# 1
# 4
# 10
# 17
# 29
# 42
# 64
# 85
# 99
# 140
# 1
# 4
# 11
# 19
# 30
# 45
# 63
# 152
# 111
# 133
# 1
# 3
# 15
# 16
# 25
# 32
# 48
# 61
# 82
# 88
# 1
# 1
# 6
# 13
# 30
# 36
# 48
# 64
# 94
# 108
# 1
# 3
# 6
# 11
# 19
# 27
# 38
# 52
# 62
# 79
# 1
# 3
# 8
# 22
# 29
# 38
# 56
# 71
# 105
# 124
# 1
# 4
# 10
# 17
# 26
# 39
# 53
# 69
# 105
# 107
# 1
# 1
# 1
# 2
# 2
# 4
# 7
# 6
# 9
# 10
# 1
# 3
# 6
# 10
# 16
# 26
# 33
# 54
# 57
# 68
# 1
# 3
# 7
# 15
# 22
# 45
# 45
# 56
# 75
# 108
# 1
# 1
# 1
# 1
# 2
# 4
# 5
# 7
# 8
# 11
# 1
# 4
# 11
# 21
# 32
# 47
# 74
# 87
# 110
# 146
# 1
# 3
# 5
# 8
# 14
# 28
# 34
# 39
# 54
# 84
# 385570

# %%
x = (-140036.8041378972, 2.5486165590751364, -0.1998934445512417, 1183)
